# %%
#mport scipy

# %%
# scipy stands for scientific python. 
# scipy is a scientific computational library that uses for numpy modules.
# it provide more utility function for optimisation,stats and single processing.
# it was created by numpy creator.
#for measurements.

# WHY USE SCIPY ?

# it has optimised and added function that are frequently used in numpy and datascience.
# designed in C.

# %%
from scipy import constants

# %%
print(constants.liter)
# one litre as cubic meter. 1L=cubic litre
# Out:
# 0.001

# %%
constants.pi
#pi value
# Out:
# 3.141592653589793

# %%
dir(constants)
# directory function
# Out:
# ['Avogadro',
#  'Boltzmann',
#  'Btu',
#  'Btu_IT',
#  'Btu_th',
#  'ConstantWarning',
#  'G',
#  'Julian_year',
#  'N_A',
#  'Planck',
#  'R',
#  'Rydberg',
#  'Stefan_Boltzmann',
#  'Wien',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_codata',
#  '_constants',
#  '_obsolete_constants',
#  'acre',
#  'alpha',
#  'angstrom',
#  'arcmin',
#  'arcminute',
#  'arcsec',
#  'arcsecond',
#  'astronomical_unit',
#  'atm',
#  'atmosphere',
#  'atomic_mass',
#  'atto',
#  'au',
#  'bar',
#  'barrel',
#  'bbl',
#  'blob',
#  'c',
#  'calorie',
#  'calorie_IT',
#  'calorie_th',
#  'carat',
#  'centi',
#  'codata',
#  'constants',
#  'convert_temperature',
#  'day',
#  'deci',
#  'degree',
#  'degree_Fahrenheit',
#  'deka',
#  'dyn',
#  'dyne',
#  'e',
#  'eV',
#  'electron_mass',
#  'electron_volt',
#  'elementary_charge',
#  'epsilon_0',
#  'erg',
#  'exa',
#  'exbi',
# ...

# %%
# unit calculation

constants.giga
# Out:
# 1000000000.0

# %%
constants.yotta
# Out:
# 1e+24

# %%
constants.zetta
# Out:
# 1e+21

# %%
constants.exa
# Out:
# 1e+18

# %%
constants.peta
# Out:
# 1000000000000000.0

# %%
constants.tera
# Out:
# 1000000000000.0

# %%
constants.mega
# Out:
# 1000000.0

# %%
constants.kilo
# Out:
# 1000.0

# %%
constants.hecto
# Out:
# 100.0

# %%
constants.deka
# Out:
# 10.0

# %%
constants.deci
# Out:
# 0.1

# %%
constants.centi
# Out:
# 0.01

# %%
constants.milli
# Out:
# 0.001

# %%
constants.micro
# Out:
# 1e-06

# %%
constants.nano
# Out:
# 1e-09

# %%
constants.pico
# Out:
# 1e-12

# %%
constants.femto
# Out:
# 1e-15

# %%
constants.zepto
# Out:
# 1e-21

# %%
constants.atto
# Out:
# 1e-18

# %%
constants.kibi
#till now matrix calculations (specific unit)(SI)
# Out:
# 1024

# %%
#binary units

constants.kibi
# Out:
# 1024

# %%
constants.mebi
# Out:
# 1048576

# %%
constants.tera
# Out:
# 1000000000000.0

# %%
constants.gibi
# Out:
# 1073741824

# %%
constants.tebi
# Out:
# 1099511627776

# %%
constants.pebi
# Out:
# 1125899906842624

# %%
constants.zebi
# Out:
# 1180591620717411303424

# %%
constants.yobi
# Out:
# 1208925819614629174706176

# %%
# Mass calculation

constants.gram
constants.pound
constants.stone
constants.grain
constants.long_ton
# Out:
# 1016.0469088

# %%
constants.short_ton
# Out:
# 907.1847399999999

# %%
# angle units

constants.degree
# Out:
# 0.017453292519943295

# %%
constants.arcmin
# Out:
# 0.0002908882086657216

# %%
constants.arcminute
# Out:
# 0.0002908882086657216

# %%
constants.arcsec
# Out:
# 4.84813681109536e-06

# %%
# time cal.

constants.minute
# Out:
# 60.0

# %%
constants.year
# Out:
# 31536000.0

# %%
constants.week
# Out:
# 604800.0

# %%
constants.day
# Out:
# 86400.0

# %%
from scipy.optimize import root

# %%
#sci optimize.root is used to find the root of the function numerically.

import numpy as np

# %%
def root1(x):
    return x**2-4
p=root(root1,x0=-1) 
print(p.x)
# Out:
# [-2.]

# %%
#linear algebra

#2x+3y=8
#5x+7y=19

from scipy.linalg import solve

# %%
a=np.array([[2,3],[5,7]])
b=np.array([8,19])
p=solve(a,b)
print(p)
# Out:
# [1. 2.]
